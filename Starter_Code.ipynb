# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(['EIN', 'NAME'], axis=1)
application_df
# Out:
#       APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0                  T10       Independent          C1000    ProductDev
# 1                   T3       Independent          C2000  Preservation
# 2                   T5  CompanySponsored          C3000    ProductDev
# 3                   T3  CompanySponsored          C2000  Preservation
# 4                   T3       Independent          C1000     Heathcare
# ...                ...               ...            ...           ...
# 34294               T4       Independent          C1000    ProductDev
# 34295               T4  CompanySponsored          C3000    ProductDev
# 34296               T3  CompanySponsored          C2000  Preservation
# 34297               T5       Independent          C3000    ProductDev
# 34298               T3       Independent          C1000  Preservation
#
#        ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS   ASK_AMT  \
# 0       Association       1              0                      N      5000
# 1      Co-operative       1         1-9999                      N    108590
# 2       Association       1              0                      N      5000
# 3             Trust       1    10000-24999                      N      6692
# 4             Trust       1  100000-499999                      N    142590
# ...             ...     ...            ...                    ...       ...
# 34294   Association       1              0                      N      5000
# 34295   Association       1              0                      N      5000
# 34296   Association       1              0                      N      5000
# 34297   Association       1              0                      N      5000
# 34298  Co-operative       1          1M-5M                      N  36500179
#
#        IS_SUCCESSFUL
# 0                  1
# 1                  1
# 2                  0
# 3                  1
# 4                  1
# ...              ...
# 34294              0
# 34295              0
# 34296              0
# 34297              1
# 34298              0
#
# [34299 rows x 10 columns]

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
application_counts = application_df['APPLICATION_TYPE'].value_counts()
application_counts
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
cutoff_value = 100
application_types_to_replace = list(application_counts[application_counts < cutoff_value].index)

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# T9         156
# Other      120
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
classification_counts = application_df['CLASSIFICATION'].value_counts()
classification_counts
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
classification_counts[classification_counts > 1]
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
cutoff_value = 1000
classifications_to_replace = list(classification_counts[classification_counts < cutoff_value].index)

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
categorical_columns = ['APPLICATION_TYPE', 'AFFILIATION', 'USE_CASE', 'ORGANIZATION', 'INCOME_AMT', 'SPECIAL_CONSIDERATIONS', 'CLASSIFICATION']
application_df = pd.get_dummies(application_df, columns=categorical_columns)

# %%
# Split our preprocessed data into our features and target arrays
X = application_df.drop(columns=['IS_SUCCESSFUL'])
y = application_df['IS_SUCCESSFUL']

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
#  YOUR CODE GOES HERE

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=80, activation='relu', input_dim=X_train_scaled.shape[1]))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=30, activation='relu'))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 80)                3600
#
#  dense_4 (Dense)             (None, 30)                2430
#
#  dense_5 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 6,061
# Trainable params: 6,061
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(
    loss='binary_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
    )

# %%
# Train the model
nn.fit(X_train_scaled, y_train, epochs=100,verbose=2)
# Out:
# Epoch 1/100
# 804/804 - 2s - loss: 0.5320 - accuracy: 0.7407 - 2s/epoch - 3ms/step
# Epoch 2/100
# 804/804 - 4s - loss: 0.5330 - accuracy: 0.7407 - 4s/epoch - 5ms/step
# Epoch 3/100
# 804/804 - 1s - loss: 0.5318 - accuracy: 0.7418 - 1s/epoch - 2ms/step
# Epoch 4/100
# 804/804 - 1s - loss: 0.5324 - accuracy: 0.7408 - 1s/epoch - 2ms/step
# Epoch 5/100
# 804/804 - 1s - loss: 0.5321 - accuracy: 0.7411 - 1s/epoch - 2ms/step
# Epoch 6/100
# 804/804 - 1s - loss: 0.5319 - accuracy: 0.7411 - 1s/epoch - 2ms/step
# Epoch 7/100
# 804/804 - 1s - loss: 0.5322 - accuracy: 0.7405 - 1s/epoch - 2ms/step
# Epoch 8/100
# 804/804 - 1s - loss: 0.5319 - accuracy: 0.7414 - 1s/epoch - 2ms/step
# Epoch 9/100
# 804/804 - 1s - loss: 0.5321 - accuracy: 0.7414 - 1s/epoch - 1ms/step
# Epoch 10/100
# 804/804 - 1s - loss: 0.5320 - accuracy: 0.7413 - 1s/epoch - 2ms/step
# Epoch 11/100
# 804/804 - 2s - loss: 0.5316 - accuracy: 0.7412 - 2s/epoch - 2ms/step
# Epoch 12/100
# 804/804 - 1s - loss: 0.5318 - accuracy: 0.7411 - 1s/epoch - 2ms/step
# Epoch 13/100
# 804/804 - 1s - loss: 0.5318 - accuracy: 0.7407 - 1s/epoch - 2ms/step
# Epoch 14/100
# 804/804 - 1s - loss: 0.5317 - accuracy: 0.7409 - 1s/epoch - 2ms/step
# Epoch 15/100
# 804/804 - 1s - loss: 0.5320 - accuracy: 0.7417 - 1s/epoch - 1ms/step
# Epoch 16/100
# 804/804 - 1s - loss: 0.5326 - accuracy: 0.7414 - 1s/epoch - 1ms/step
# Epoch 17/100
# 804/804 - 1s - loss: 0.5315 - accuracy: 0.7412 - 1s/epoch - 2ms/step
# Epoch 18/100
# 804/804 - 1s - loss: 0.5317 - accuracy: 0.7418 - 1s/epoch - 2ms/step
# Epoch 19/100
# 804/804 - 1s - loss: 0.5318 - accuracy: 0.7414 - 1s/epoch - 2ms/step
# Epoch 20/100
# 804/804 - 2s - loss: 0.5317 - accuracy: 0.7404 - 2s/epoch - 2ms/step
# Epoch 21/100
# 804/804 - 2s - loss: 0.5316 - accuracy: 0.7418 - 2s/epoch - 2ms/step
# Epoch 22/100
# 804/804 - 2s - loss: 0.5319 - accuracy: 0.7411 - 2s/epoch - 2ms/step
# Epoch 23/100
# 804/804 - 1s - loss: 0.5314 - accuracy: 0.7412 - 1s/epoch - 2ms/step
# Epoch 24/100
# 804/804 - 1s - loss: 0.5314 - accuracy: 0.7406 - 1s/epoch - 1ms/step
# Epoch 25/100
# 804/804 - 1s - loss: 0.5320 - accuracy: 0.7412 - 1s/epoch - 2ms/step
# Epoch 26/100
# 804/804 - 1s - loss: 0.5316 - accuracy: 0.7418 - 1s/epoch - 1ms/step
# Epoch 27/100
# 804/804 - 1s - loss: 0.5321 - accuracy: 0.7413 - 1s/epoch - 2ms/step
# Epoch 28/100
# 804/804 - 1s - loss: 0.5315 - accuracy: 0.7412 - 1s/epoch - 1ms/step
# Epoch 29/100
# 804/804 - 1s - loss: 0.5321 - accuracy: 0.7414 - 1s/epoch - 2ms/step
# Epoch 30/100
# 804/804 - 2s - loss: 0.5315 - accuracy: 0.7410 - 2s/epoch - 2ms/step
# Epoch 31/100
# 804/804 - 2s - loss: 0.5325 - accuracy: 0.7415 - 2s/epoch - 2ms/step
# Epoch 32/100
# 804/804 - 1s - loss: 0.5316 - accuracy: 0.7411 - 1s/epoch - 2ms/step
# Epoch 33/100
# 804/804 - 1s - loss: 0.5314 - accuracy: 0.7420 - 1s/epoch - 2ms/step
# Epoch 34/100
# 804/804 - 1s - loss: 0.5314 - accuracy: 0.7416 - 1s/epoch - 1ms/step
# Epoch 35/100
# 804/804 - 1s - loss: 0.5316 - accuracy: 0.7415 - 1s/epoch - 1ms/step
# Epoch 36/100
# 804/804 - 1s - loss: 0.5324 - accuracy: 0.7419 - 1s/epoch - 2ms/step
# Epoch 37/100
# 804/804 - 1s - loss: 0.5312 - accuracy: 0.7417 - 1s/epoch - 2ms/step
# Epoch 38/100
# 804/804 - 1s - loss: 0.5313 - accuracy: 0.7420 - 1s/epoch - 1ms/step
# Epoch 39/100
# 804/804 - 1s - loss: 0.5317 - accuracy: 0.7419 - 1s/epoch - 2ms/step
# Epoch 40/100
# 804/804 - 2s - loss: 0.5318 - accuracy: 0.7409 - 2s/epoch - 2ms/step
# Epoch 41/100
# 804/804 - 1s - loss: 0.5314 - accuracy: 0.7409 - 1s/epoch - 2ms/step
# Epoch 42/100
# 804/804 - 1s - loss: 0.5314 - accuracy: 0.7410 - 1s/epoch - 2ms/step
# Epoch 43/100
# 804/804 - 1s - loss: 0.5310 - accuracy: 0.7415 - 1s/epoch - 1ms/step
# Epoch 44/100
# 804/804 - 1s - loss: 0.5319 - accuracy: 0.7412 - 1s/epoch - 1ms/step
# Epoch 45/100
# 804/804 - 1s - loss: 0.5310 - accuracy: 0.7418 - 1s/epoch - 1ms/step
# Epoch 46/100
# 804/804 - 1s - loss: 0.5316 - accuracy: 0.7416 - 1s/epoch - 2ms/step
# Epoch 47/100
# 804/804 - 1s - loss: 0.5311 - accuracy: 0.7407 - 1s/epoch - 2ms/step
# Epoch 48/100
# 804/804 - 1s - loss: 0.5317 - accuracy: 0.7417 - 1s/epoch - 1ms/step
# Epoch 49/100
# 804/804 - 1s - loss: 0.5312 - accuracy: 0.7415 - 1s/epoch - 2ms/step
# Epoch 50/100
# 804/804 - 2s - loss: 0.5316 - accuracy: 0.7410 - 2s/epoch - 2ms/step
# Epoch 51/100
# 804/804 - 1s - loss: 0.5330 - accuracy: 0.7414 - 1s/epoch - 2ms/step
# Epoch 52/100
# 804/804 - 1s - loss: 0.5316 - accuracy: 0.7406 - 1s/epoch - 2ms/step
# Epoch 53/100
# 804/804 - 1s - loss: 0.5316 - accuracy: 0.7415 - 1s/epoch - 1ms/step
# Epoch 54/100
# 804/804 - 1s - loss: 0.5317 - accuracy: 0.7410 - 1s/epoch - 1ms/step
# Epoch 55/100
# 804/804 - 1s - loss: 0.5313 - accuracy: 0.7415 - 1s/epoch - 2ms/step
# Epoch 56/100
# 804/804 - 1s - loss: 0.5324 - accuracy: 0.7417 - 1s/epoch - 2ms/step
# Epoch 57/100
# 804/804 - 1s - loss: 0.5310 - accuracy: 0.7414 - 1s/epoch - 1ms/step
# Epoch 58/100
# 804/804 - 1s - loss: 0.5310 - accuracy: 0.7416 - 1s/epoch - 2ms/step
# Epoch 59/100
# 804/804 - 2s - loss: 0.5314 - accuracy: 0.7415 - 2s/epoch - 2ms/step
# Epoch 60/100
# 804/804 - 2s - loss: 0.5312 - accuracy: 0.7414 - 2s/epoch - 2ms/step
# Epoch 61/100
# 804/804 - 1s - loss: 0.5316 - accuracy: 0.7416 - 1s/epoch - 2ms/step
# Epoch 62/100
# 804/804 - 1s - loss: 0.5320 - accuracy: 0.7412 - 1s/epoch - 2ms/step
# Epoch 63/100
# 804/804 - 1s - loss: 0.5314 - accuracy: 0.7407 - 1s/epoch - 2ms/step
# Epoch 64/100
# 804/804 - 1s - loss: 0.5313 - accuracy: 0.7416 - 1s/epoch - 2ms/step
# Epoch 65/100
# 804/804 - 1s - loss: 0.5316 - accuracy: 0.7411 - 1s/epoch - 2ms/step
# Epoch 66/100
# 804/804 - 1s - loss: 0.5309 - accuracy: 0.7416 - 1s/epoch - 2ms/step
# Epoch 67/100
# 804/804 - 1s - loss: 0.5311 - accuracy: 0.7412 - 1s/epoch - 1ms/step
# Epoch 68/100
# 804/804 - 1s - loss: 0.5314 - accuracy: 0.7418 - 1s/epoch - 2ms/step
# Epoch 69/100
# 804/804 - 2s - loss: 0.5313 - accuracy: 0.7425 - 2s/epoch - 2ms/step
# Epoch 70/100
# 804/804 - 1s - loss: 0.5314 - accuracy: 0.7410 - 1s/epoch - 2ms/step
# Epoch 71/100
# 804/804 - 1s - loss: 0.5311 - accuracy: 0.7420 - 1s/epoch - 2ms/step
# Epoch 72/100
# 804/804 - 1s - loss: 0.5329 - accuracy: 0.7416 - 1s/epoch - 2ms/step
# Epoch 73/100
# 804/804 - 1s - loss: 0.5320 - accuracy: 0.7419 - 1s/epoch - 2ms/step
# Epoch 74/100
# 804/804 - 1s - loss: 0.5311 - accuracy: 0.7414 - 1s/epoch - 1ms/step
# Epoch 75/100
# 804/804 - 1s - loss: 0.5312 - accuracy: 0.7413 - 1s/epoch - 2ms/step
# Epoch 76/100
# 804/804 - 1s - loss: 0.5314 - accuracy: 0.7416 - 1s/epoch - 1ms/step
# Epoch 77/100
# 804/804 - 1s - loss: 0.5312 - accuracy: 0.7410 - 1s/epoch - 1ms/step
# Epoch 78/100
# 804/804 - 1s - loss: 0.5311 - accuracy: 0.7413 - 1s/epoch - 2ms/step
# Epoch 79/100
# 804/804 - 2s - loss: 0.5312 - accuracy: 0.7414 - 2s/epoch - 2ms/step
# Epoch 80/100
# 804/804 - 1s - loss: 0.5311 - accuracy: 0.7413 - 1s/epoch - 2ms/step
# Epoch 81/100
# 804/804 - 1s - loss: 0.5311 - accuracy: 0.7409 - 1s/epoch - 1ms/step
# Epoch 82/100
# 804/804 - 1s - loss: 0.5309 - accuracy: 0.7419 - 1s/epoch - 2ms/step
# Epoch 83/100
# 804/804 - 1s - loss: 0.5310 - accuracy: 0.7416 - 1s/epoch - 1ms/step
# Epoch 84/100
# 804/804 - 1s - loss: 0.5308 - accuracy: 0.7414 - 1s/epoch - 1ms/step
# Epoch 85/100
# 804/804 - 1s - loss: 0.5311 - accuracy: 0.7411 - 1s/epoch - 1ms/step
# Epoch 86/100
# 804/804 - 1s - loss: 0.5309 - accuracy: 0.7416 - 1s/epoch - 1ms/step
# Epoch 87/100
# 804/804 - 1s - loss: 0.5309 - accuracy: 0.7416 - 1s/epoch - 1ms/step
# Epoch 88/100
# 804/804 - 2s - loss: 0.5313 - accuracy: 0.7410 - 2s/epoch - 2ms/step
# Epoch 89/100
# 804/804 - 2s - loss: 0.5306 - accuracy: 0.7416 - 2s/epoch - 2ms/step
# Epoch 90/100
# 804/804 - 1s - loss: 0.5308 - accuracy: 0.7417 - 1s/epoch - 2ms/step
# Epoch 91/100
# 804/804 - 1s - loss: 0.5306 - accuracy: 0.7417 - 1s/epoch - 1ms/step
# Epoch 92/100
# 804/804 - 1s - loss: 0.5309 - accuracy: 0.7409 - 1s/epoch - 1ms/step
# Epoch 93/100
# 804/804 - 1s - loss: 0.5309 - accuracy: 0.7416 - 1s/epoch - 1ms/step
# Epoch 94/100
# 804/804 - 1s - loss: 0.5309 - accuracy: 0.7416 - 1s/epoch - 1ms/step
# Epoch 95/100
# 804/804 - 1s - loss: 0.5312 - accuracy: 0.7420 - 1s/epoch - 1ms/step
# Epoch 96/100
# 804/804 - 1s - loss: 0.5310 - accuracy: 0.7418 - 1s/epoch - 1ms/step
# Epoch 97/100
# 804/804 - 1s - loss: 0.5306 - accuracy: 0.7420 - 1s/epoch - 1ms/step
# Epoch 98/100
# 804/804 - 2s - loss: 0.5306 - accuracy: 0.7414 - 2s/epoch - 2ms/step
# Epoch 99/100
# 804/804 - 2s - loss: 0.5304 - accuracy: 0.7420 - 2s/epoch - 2ms/step
# Epoch 100/100
# 804/804 - 1s - loss: 0.5310 - accuracy: 0.7420 - 1s/epoch - 1ms/step

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5809 - accuracy: 0.7285 - 326ms/epoch - 1ms/step
# Loss: 0.5808796882629395, Accuracy: 0.7285131216049194

# %%
# Export our model to HDF5 file
nn.save("AlphabetSoupCharity.h5")
